# %% [markdown]
# # SDF Results
#
# Review the pricing-kernel track through IPCA and neural-SDF prediction diagnostics, factor-spanning evidence, and portfolio alphas.

# %%
from pathlib import Path
import json

import pandas as pd

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent


def read_json(path):
    return json.loads((ROOT / path).read_text(encoding="utf-8"))


def maybe_read_csv(path, **kwargs):
    p = ROOT / path
    if not p.exists():
        return pd.DataFrame()
    return pd.read_csv(p, **kwargs)

ROOT

# %% [markdown]
# ## Prediction Track Metrics

# %%
metrics = read_json("artifacts/full/metrics.json")
models = metrics.get("models", {})
{k: v for k, v in models.items() if "ipca" in k or "neural" in k}

# %% [markdown]
# ## Alpha Diagnostics

# %%
results = read_json("docs/assets/results_manifest.json")
results.get("diagnostics", {}).get("factor_alpha_spanning")

# %%
from IPython.display import Image, display
for rel in [
    "artifacts/figures/full/alpha_bar.png",
    "artifacts/figures/full/turnover_cost_decomposition.png",
]:
    path = ROOT / rel
    if path.exists():
        display(Image(filename=str(path)))
